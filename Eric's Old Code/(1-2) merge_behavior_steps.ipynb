# %% [markdown]
# # Ground Truth and Step Count Merge

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load and Check Data Integrity

# %% [markdown]
# **Coding Ground Truth**

# %%
# Import coding ground truth
ground_truth = pd.read_csv("ACT24_groundtruth_secbysec_20250415.csv", dtype={"work_type": "string"}) #dtype since missing values were stored as NaN, should be as pd.na

# %%
# Display first 5 rows for inspection
ground_truth.head()
# Out:
#     id  observation        date            date_time activity_type  \
# 0  102            1  2019-07-24  2019-07-24 08:20:19  WRK- general
# 1  102            1  2019-07-24  2019-07-24 08:20:20  WRK- general
# 2  102            1  2019-07-24  2019-07-24 08:20:21  WRK- general
# 3  102            1  2019-07-24  2019-07-24 08:20:22  WRK- general
# 4  102            1  2019-07-24  2019-07-24 08:20:23  WRK- general
#
#   broad_activity_type                          work_type posture  \
# 0      work_education  SP- Education and Health Services   stand
# 1      work_education  SP- Education and Health Services   stand
# 2      work_education  SP- Education and Health Services   stand
# 3      work_education  SP- Education and Health Services   stand
# 4      work_education  SP- Education and Health Services   stand
#
#    sedentary_not  walking_not activity_intensity
# 0  not_sedentary  not_walking              light
# 1  not_sedentary  not_walking              light
# 2  not_sedentary  not_walking              light
# 3  not_sedentary  not_walking              light
# 4  not_sedentary  not_walking              light

# %%
# Check for duplicate timestamps
check = ground_truth[["id", "observation", "date_time"]].value_counts()
check[check > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# **Steps Ground Truth**

# %%
# Import seconds ground truth
seconds = pd.read_csv("/Users/hydeet/Library/CloudStorage/OneDrive-CalPoly/StepCount/Eric's Analysis/Required datasets/seconds_ground_truth_20250410.csv")

# %%
seconds["Quality"].value_counts()
# Out:
# Quality
# Codable         388676
# Non-codeable      6108
# Name: count, dtype: int64

# %%
# Display first 5 rows for inspection
seconds.sort_values(["ID", "Session", "Date", "Time"]).head()
# Out:
#          ID  Session relative_time_steps       Date      Time  Quality  Step
# 229026  102        1             0:00:01  7/24/2019  08:20:20  Codable     0
# 229027  102        1             0:00:02  7/24/2019  08:20:21  Codable     0
# 229028  102        1             0:00:03  7/24/2019  08:20:22  Codable     0
# 229029  102        1             0:00:04  7/24/2019  08:20:23  Codable     0
# 229030  102        1             0:00:05  7/24/2019  08:20:24  Codable     1

# %%
# Check for duplicate timestamps
check = seconds[["ID", "Session", "Date", "Time"]].value_counts()
# Duplicate timestamps were found, check for specific rows and step counts
check[check > 1].reset_index().merge(right = seconds, on=["ID", "Session", "Date", "Time"])
# Out:
#         ID  Session        Date      Time  count relative_time_steps  Quality  \
# 0      135        1  10/15/2019  05:49:58      2             2:18:13  Codable
# 1      135        1  10/15/2019  05:49:58      2             2:18:13  Codable
# 2      135        1  10/15/2019  05:29:08      2             1:57:23  Codable
# 3      135        1  10/15/2019  05:29:08      2             1:57:23  Codable
# 4      135        1  10/15/2019  05:29:00      2             1:57:15  Codable
# ...    ...      ...         ...       ...    ...                 ...      ...
# 21507  135        1  10/15/2019  04:29:16      2             0:57:31  Codable
# 21508  135        1  10/15/2019  04:29:17      2             0:57:32  Codable
# 21509  135        1  10/15/2019  04:29:17      2             0:57:32  Codable
# 21510  135        1  10/15/2019  04:29:18      2             0:57:33  Codable
# 21511  135        1  10/15/2019  04:29:18      2             0:57:33  Codable
#
#        Step
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 21507     0
# 21508     0
# 21509     0
# 21510     0
# 21511     0
#
# [21512 rows x 8 columns]

# %% [markdown]
# ## Ground Truth Data Cleaning

# %%
def quality_agg(srs):
    if "Non-codable" in srs:
        return "Non-codeable"
    return srs.iloc[0]

# %%
seconds_2 = seconds.copy()
# Rename columns
seconds_2.rename(columns={"ID": "id", "Session": "observation"}, inplace=True)
# Remove duplicates
# Logic: Get max step count for each timestamp
seconds_2 = seconds_2.groupby(["id", "observation", "Date", "Time", "relative_time_steps"]).agg({'Quality': quality_agg, 'Step': 'max'}).reset_index()
# Create datetime column
seconds_2["date_time"] = pd.to_datetime(seconds_2['Date'] + ' ' + seconds_2['Time'])
seconds_2
# Out:
#          id  observation       Date      Time relative_time_steps  Quality  \
# 0       102            1  7/24/2019  08:20:20             0:00:01  Codable
# 1       102            1  7/24/2019  08:20:21             0:00:02  Codable
# 2       102            1  7/24/2019  08:20:22             0:00:03  Codable
# 3       102            1  7/24/2019  08:20:23             0:00:04  Codable
# 4       102            1  7/24/2019  08:20:24             0:00:05  Codable
# ...     ...          ...        ...       ...                 ...      ...
# 384023  154            2  2/23/2020  01:06:11             0:02:20  Codable
# 384024  154            2  2/23/2020  01:06:12             0:02:21  Codable
# 384025  154            2  2/23/2020  01:06:13             0:02:22  Codable
# 384026  154            2  2/23/2020  01:06:14             0:02:23  Codable
# 384027  154            2  2/23/2020  01:06:15             0:02:24  Codable
#
#         Step           date_time
# 0          0 2019-07-24 08:20:20
# 1          0 2019-07-24 08:20:21
# 2          0 2019-07-24 08:20:22
# 3          0 2019-07-24 08:20:23
# 4          1 2019-07-24 08:20:24
# ...      ...                 ...
# 384023     1 2020-02-23 01:06:11
# 384024     2 2020-02-23 01:06:12
# 384025     2 2020-02-23 01:06:13
# 384026     1 2020-02-23 01:06:14
# 384027     2 2020-02-23 01:06:15
#
# [384028 rows x 8 columns]

# %%
seconds_2["Quality"].value_counts()
# Out:
# Quality
# Codable         377920
# Non-codeable      6108
# Name: count, dtype: int64

# %%
# Check for duplicates again
check = seconds_2[["id", "observation", "date_time"]].value_counts()
check[check > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
ground_truth_2 = ground_truth.copy()
# Create datetime column
ground_truth_2["date_time"] = pd.to_datetime(ground_truth["date_time"])
ground_truth_2
# Out:
#          id  observation        date           date_time  \
# 0       102            1  2019-07-24 2019-07-24 08:20:19
# 1       102            1  2019-07-24 2019-07-24 08:20:20
# 2       102            1  2019-07-24 2019-07-24 08:20:21
# 3       102            1  2019-07-24 2019-07-24 08:20:22
# 4       102            1  2019-07-24 2019-07-24 08:20:23
# ...     ...          ...         ...                 ...
# 511814  154            2  2020-02-23 2020-02-23 15:55:47
# 511815  154            2  2020-02-23 2020-02-23 15:55:48
# 511816  154            2  2020-02-23 2020-02-23 15:55:49
# 511817  154            2  2020-02-23 2020-02-23 15:55:50
# 511818  154            2  2020-02-23 2020-02-23 15:55:51
#
#                                 activity_type broad_activity_type  \
# 0                                WRK- general      work_education
# 1                                WRK- general      work_education
# 2                                WRK- general      work_education
# 3                                WRK- general      work_education
# 4                                WRK- general      work_education
# ...                                       ...                 ...
# 511814  EDU- taking class, research, homework      work_education
# 511815  EDU- taking class, research, homework      work_education
# 511816  EDU- taking class, research, homework      work_education
# 511817  EDU- taking class, research, homework      work_education
# 511818  EDU- taking class, research, homework      work_education
#
#                                 work_type  posture  sedentary_not  \
# 0       SP- Education and Health Services    stand  not_sedentary
# 1       SP- Education and Health Services    stand  not_sedentary
# 2       SP- Education and Health Services    stand  not_sedentary
# 3       SP- Education and Health Services    stand  not_sedentary
# 4       SP- Education and Health Services    stand  not_sedentary
# ...                                   ...      ...            ...
# 511814                               <NA>  sitting      sedentary
# 511815                               <NA>  sitting      sedentary
# 511816                               <NA>  sitting      sedentary
# 511817                               <NA>  sitting      sedentary
# 511818                               <NA>  sitting      sedentary
#
#         walking_not activity_intensity
# 0       not_walking              light
# 1       not_walking              light
# 2       not_walking              light
# 3       not_walking              light
# 4       not_walking              light
# ...             ...                ...
# 511814  not_walking          sedentary
# 511815  not_walking          sedentary
# 511816  not_walking          sedentary
# 511817  not_walking          sedentary
# 511818  not_walking          sedentary
#
# [511819 rows x 11 columns]

# %% [markdown]
# ## Check Start and End Times of Both Files

# %%
# Function to get start and end info for each id and session
def start_end(GT, id, session): 
    subset = GT[(GT["id"] == id) & (GT["observation"] == session)].reset_index(drop=True)
    start = min(subset["date_time"])
    end = max(subset["date_time"])
    # for i, row in subset.iterrows():
    #     if i != 0:
    #         if row["date_time"] < start:
    #             start = row["date_time"]
    #         elif row["date_time"] > end:
    #             end = row["date_time"]
    return [start, end]
    #print(f"ID = {id}, Session = {session}, Start = {start}, End = {end}")

# %%
# Function to apply start_end to entire dataframe (ie. each id and session)
def start_time_dataframe(df):
    id_ses = df.groupby(["id", "observation"]).size().reset_index().rename(columns={0: "count"})
    times = {"ID": [], 
                   "Session": [],
                   "Start": [],
                   "End": []}
    for i, row in id_ses.iterrows():
        times["ID"].append(row["id"])
        times["Session"].append(row["observation"])
        ls = start_end(df, row["id"], row["observation"])
        times["Start"].append(ls[0])
        times["End"].append(ls[1])
    return pd.DataFrame(times)

# %%
# Get start and end times from both coding and step ground truths
GT_times = start_time_dataframe(ground_truth_2)
seconds_times = start_time_dataframe(seconds_2)

# %%
start_end_info = pd.merge(GT_times, seconds_times, on=["ID", "Session"], how="outer", suffixes=("_GT", '_secondsFile'))
# Get differences between seconds/coding ground truth, in seconds
start_end_info["StartDiffSecs(GT-seconds)"] = (start_end_info["Start_GT"] - start_end_info["Start_secondsFile"]).dt.total_seconds()
start_end_info["EndDiffSecs(GT-seconds)"] = (start_end_info["End_GT"] - start_end_info["End_secondsFile"]).dt.total_seconds()
start_end_info
# Out:
#      ID  Session            Start_GT              End_GT   Start_secondsFile  \
# 29 2019-10-19 15:40:11                       -1.0                    590.0
# 30 2019-10-17 04:40:55                    43201.0                  43205.0
# 31                 NaT                        NaN                      NaN
# 32 2019-11-01 06:00:31                    43204.0                  43229.0
# 33                 NaT                        NaN                      NaN
# 34                 NaT                        NaN                      NaN
# 35                 NaT                        NaN                      NaN
# 36 2019-11-09 11:39:11                       42.0                   1190.0
# 37 2019-11-09 03:23:11                    43208.0                  45649.0
# 38 2019-11-06 15:27:59                       -1.0                     61.0
# 39 2019-11-10 13:00:09                        6.0                     51.0
# 40 2019-11-18 04:02:03                    43199.0                  43195.0
# 41 2019-11-16 13:04:57                        8.0                    123.0
# 42 2019-11-22 15:38:02                        8.0                     58.0
# 43 2019-11-23 07:06:26                    43205.0                  44913.0
# 44 2020-01-19 13:17:51                        8.0                     35.0
# 45 2020-01-21 10:25:49                    43206.0                  43571.0
# 46                 NaT                        NaN                      NaN
# 47 2020-02-23 01:06:15                    43208.0                  53376.0

# %% [markdown]
# **Add Issue Flags in Columns**

# %%
# Function that flags id/observation pairs if the times between step and coding ground truth are off by around 12 hrs
def flag_military(row):
    if row > 40000:
        return True
    else:
        return False

# %%
start_end_info_2 = start_end_info.copy()
start_end_info_2["MilitaryTimeFlag"] = start_end_info_2["StartDiffSecs(GT-seconds)"].apply(flag_military)
start_end_info_2
# Out:
#      ID  Session            Start_GT              End_GT   Start_secondsFile  \
# 0   102        1 2019-07-24 08:20:19 2019-07-24 11:21:13 2019-07-24 08:20:20
# 1   102        2 2019-07-25 12:42:08 2019-07-25 15:42:00 2019-07-25 12:41:53
# 2   116        1 2019-08-20 08:08:45 2019-08-20 11:09:00 2019-08-20 08:08:46
# 3   116        2 2019-08-21 11:10:12 2019-08-21 13:28:00 2019-08-21 11:09:48
# 4   117        1 2019-08-20 15:17:46 2019-08-20 18:18:00 2019-08-20 03:17:47
# 5   117        2 2019-08-21 07:11:45 2019-08-21 10:13:00 2019-08-21 07:11:46
# 6   122        1 2019-08-28 10:06:40 2019-08-28 13:06:59 2019-08-28 10:06:41
# 7   122        2 2019-08-29 15:19:51 2019-08-29 18:23:00 2019-08-29 03:19:52
# 8   124        1 2019-08-28 14:59:09 2019-08-28 17:59:05 2019-08-28 02:58:52
# 9   124        2 2019-08-29 09:31:00 2019-08-29 12:31:00 2019-08-29 09:30:40
# 10  126        1 2019-09-02 11:14:51 2019-09-02 14:15:00                 NaT
# 11  126        2 2019-09-06 10:36:07 2019-09-06 13:36:07 2019-09-06 10:35:54
# 12  127        1 2019-09-05 16:07:56 2019-09-05 19:08:00 2019-09-05 04:07:57
# 13  127        2 2019-09-09 10:56:04 2019-09-09 13:56:00 2019-09-09 10:55:57
# 14  128        1 2019-09-06 07:00:00 2019-09-06 09:59:59 2019-09-06 06:59:52
# 15  128        2 2019-09-10 13:21:00 2019-09-10 16:17:00 2019-09-10 01:20:59
# 16  129        1 2019-09-07 08:55:00 2019-09-07 11:55:00 2019-09-07 08:54:49
# 3  2019-08-21 13:26:58                       24.0                     62.0
# 4  2019-08-20 06:05:55                    43199.0                  43925.0
# 5  2019-08-21 09:41:43                       -1.0                   1877.0
# 6  2019-08-28 12:42:20                       -1.0                   1479.0
# 7  2019-08-29 06:22:41                    43199.0                  43219.0
# 8  2019-08-28 04:49:39                    43217.0                  47366.0
# 9  2019-08-29 12:18:54                       20.0                    726.0
# 10                 NaT                        NaN                      NaN
# 11 2019-09-06 12:51:09                       13.0                   2698.0
# 12 2019-09-05 06:28:24                    43199.0                  45576.0
# 13 2019-09-09 13:37:25                        7.0                   1115.0
# 14 2019-09-06 08:55:37                        8.0                   3862.0
# 15 2019-09-10 04:16:34                    43201.0                  43226.0
# 16 2019-09-07 11:52:55                       11.0                    125.0
# 17 2019-09-10 07:28:34                    43199.0                  43405.0
# 18 2019-09-08 08:25:48                    43199.0                  43325.0
# 19 2019-09-10 10:48:50                        9.0                    790.0
# 20 2019-09-12 13:57:50                       -1.0                     10.0
# 21                 NaT                        NaN                      NaN
# 22 2019-10-04 04:27:17                    43234.0                  43422.0
# 23 2019-10-10 12:06:49                       13.0                     11.0
# 24 2019-10-10 04:41:33                    43199.0                  46193.0
# 25 2019-10-11 13:22:47                       39.0                     13.0
# 26 2019-10-09 15:41:57                       14.0                    -12.0
# 27                 NaT                        NaN                      NaN
# 28 2019-10-15 06:31:01                    43215.0                  43259.0
# 29 2019-10-19 15:40:11                       -1.0                    590.0
# 30 2019-10-17 04:40:55                    43201.0                  43205.0
# 31                 NaT                        NaN                      NaN
# 32 2019-11-01 06:00:31                    43204.0                  43229.0
# 33                 NaT                        NaN                      NaN
# 34                 NaT                        NaN                      NaN
# 35                 NaT                        NaN                      NaN
# 36 2019-11-09 11:39:11                       42.0                   1190.0
# 37 2019-11-09 03:23:11                    43208.0                  45649.0
# 38 2019-11-06 15:27:59                       -1.0                     61.0
# 39 2019-11-10 13:00:09                        6.0                     51.0
# 40 2019-11-18 04:02:03                    43199.0                  43195.0
# 41 2019-11-16 13:04:57                        8.0                    123.0
# 42 2019-11-22 15:38:02                        8.0                     58.0
# 43 2019-11-23 07:06:26                    43205.0                  44913.0
# 44 2020-01-19 13:17:51                        8.0                     35.0
# 45 2020-01-21 10:25:49                    43206.0                  43571.0
# 46                 NaT                        NaN                      NaN
# 47 2020-02-23 01:06:15                    43208.0                  53376.0
#
#     MilitaryTimeFlag
# 0              False
# 1              False
# 2              False
# 3              False
# 4               True
# 5              False
# 6              False
# 7               True
# 8               True
# 9              False
# 10             False
# 11             False
# 12              True
# 13             False
# 14             False
# 15              True
# 16             False
# 17              True
# 18              True
# 19             False
# 20             False
# 21             False
# 22              True
# 23             False
# 24              True
# 25             False
# 26             False
# 27             False
# 28              True
# 29             False
# 30              True
# 31             False
# 32              True
# 33             False
# 34             False
# 35             False
# 36             False
# 37              True
# 38             False
# 39             False
# 40              True
# 41             False
# 42             False
# 43              True
# 44             False
# 45              True
# 46             False
# 47              True

# %% [markdown]
# **Issues:**
# * Negative start second differences implies that the ground truth start times are OUTSIDE the seconds file session times
# * Positive end second differences implies that the ground truth end times are OUTSIDE the seconds file session times
#
# **This implies that we have tagged times for this (ID, Session) pair in our ground truth file that have no information about steps taken :(**

# %% [markdown]
# **1\. Ground Truth File contains military time timestamps but seconds file is in AM/PM**
# * MilitaryTimeFlag = True means this row has this problem
# * **NOTE**: Fixed.
#
# **2\. (ID, Session) pairs missing in seconds file (9 total)**
# * Probably just need to throw these out since we do not have step info for these :(

# %% [markdown]
# ## Fix AM/PM Disparity

# %%
start_end_info_3 = start_end_info_2.copy()
# Fix start AM/PM
start_end_info_3['Start_secondsFile'] = start_end_info_3['Start_secondsFile'] + pd.to_timedelta("12:00:00") * start_end_info_3['MilitaryTimeFlag']
# Fix end AM/PM
start_end_info_3['End_secondsFile'] = start_end_info_3['End_secondsFile'] + pd.to_timedelta("12:00:00") * start_end_info_3['MilitaryTimeFlag']
# Recalculate differences
start_end_info_3["StartDiffSecs(GT-seconds)"] = (start_end_info_3["Start_GT"] - start_end_info_3["Start_secondsFile"]).dt.total_seconds()
start_end_info_3["EndDiffSecs(GT-seconds)"] = (start_end_info_3["End_GT"] - start_end_info_3["End_secondsFile"]).dt.total_seconds()
# Recode military time flag
start_end_info_3['MilitaryTimeFlag'] = start_end_info_3["StartDiffSecs(GT-seconds)"].apply(flag_military)
# We need to determine which rows in the second-by-second data fall within the intersection of the groundtruth time intervals, since they don't match up
# Find the greatest start time
start_end_info_3['max_start'] = start_end_info_3[['Start_GT', 'Start_secondsFile']].max(axis=1)
# Find the smallest end time
start_end_info_3['min_end'] = start_end_info_3[['End_GT', 'End_secondsFile']].min(axis=1)
start_end_info_3
# Out:
#      ID  Session            Start_GT              End_GT   Start_secondsFile  \
# 0   102        1 2019-07-24 08:20:19 2019-07-24 11:21:13 2019-07-24 08:20:20
# 1   102        2 2019-07-25 12:42:08 2019-07-25 15:42:00 2019-07-25 12:41:53
# 2   116        1 2019-08-20 08:08:45 2019-08-20 11:09:00 2019-08-20 08:08:46
# 3   116        2 2019-08-21 11:10:12 2019-08-21 13:28:00 2019-08-21 11:09:48
# 4   117        1 2019-08-20 15:17:46 2019-08-20 18:18:00 2019-08-20 15:17:47
# 5   117        2 2019-08-21 07:11:45 2019-08-21 10:13:00 2019-08-21 07:11:46
# 6   122        1 2019-08-28 10:06:40 2019-08-28 13:06:59 2019-08-28 10:06:41
# 7   122        2 2019-08-29 15:19:51 2019-08-29 18:23:00 2019-08-29 15:19:52
# 8   124        1 2019-08-28 14:59:09 2019-08-28 17:59:05 2019-08-28 14:58:52
# 9   124        2 2019-08-29 09:31:00 2019-08-29 12:31:00 2019-08-29 09:30:40
# 10  126        1 2019-09-02 11:14:51 2019-09-02 14:15:00                 NaT
# 11  126        2 2019-09-06 10:36:07 2019-09-06 13:36:07 2019-09-06 10:35:54
# 12  127        1 2019-09-05 16:07:56 2019-09-05 19:08:00 2019-09-05 16:07:57
# Columns: [ID, Session, Start_GT, End_GT, Start_secondsFile, End_secondsFile, StartDiffSecs(GT-seconds), EndDiffSecs(GT-seconds), MilitaryTimeFlag, max_start, min_end]
# Index: []

# %%
# Edit steps ground truth to fix AM/PM disparities
seconds_3 = seconds_2.merge(right = start_end_info_2[["ID", "Session", "MilitaryTimeFlag", "StartDiffSecs(GT-seconds)"]], how = 'left',
              left_on = ["id", "observation"], right_on = ["ID", "Session"])
seconds_3["date_time"] = seconds_3["date_time"] + pd.to_timedelta("12:00:00") * seconds_3["MilitaryTimeFlag"]
seconds_3 = seconds_3[["id", "observation", "date_time", "Quality", "Step"]]
seconds_3
# Out:
#          id  observation           date_time  Quality  Step
# 0       102            1 2019-07-24 08:20:20  Codable     0
# 1       102            1 2019-07-24 08:20:21  Codable     0
# 2       102            1 2019-07-24 08:20:22  Codable     0
# 3       102            1 2019-07-24 08:20:23  Codable     0
# 4       102            1 2019-07-24 08:20:24  Codable     1
# ...     ...          ...                 ...      ...   ...
# 384023  154            2 2020-02-23 13:06:11  Codable     1
# 384024  154            2 2020-02-23 13:06:12  Codable     2
# 384025  154            2 2020-02-23 13:06:13  Codable     2
# 384026  154            2 2020-02-23 13:06:14  Codable     1
# 384027  154            2 2020-02-23 13:06:15  Codable     2
#
# [384028 rows x 5 columns]

# %%
# Check for duplicate times
check = seconds_3[["id", "observation", "date_time"]].value_counts()
check[check>1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
seconds_3["Quality"].value_counts()
# Out:
# Quality
# Codable         377920
# Non-codeable      6108
# Name: count, dtype: int64

# %% [markdown]
# ## Merge Ground Truth Datasets

# %%
# Outer merge coding with steps ground truth
merged = pd.merge(left = ground_truth_2, right = seconds_3, how="outer", on=["id", "observation", "date_time"])
# Add flag for times that are inside the max start and min end interval
merged = merged.merge(right = start_end_info_3[["ID", "Session", "max_start", "min_end"]], how = 'left',
                            left_on = ["id", "observation"], right_on = ["ID", "Session"])
merged["inside_flag"] = (merged["date_time"] >= merged["max_start"]) & (merged["date_time"] <= merged["min_end"])
merged = merged.drop(["ID", "Session", "max_start", "min_end"], axis=1)
merged
# Out:
#          id  observation        date           date_time  \
# 0       102            1  2019-07-24 2019-07-24 08:20:19
# 1       102            1  2019-07-24 2019-07-24 08:20:20
# 2       102            1  2019-07-24 2019-07-24 08:20:21
# 3       102            1  2019-07-24 2019-07-24 08:20:22
# 4       102            1  2019-07-24 2019-07-24 08:20:23
# ...     ...          ...         ...                 ...
# 512175  154            2  2020-02-23 2020-02-23 15:55:47
# 512176  154            2  2020-02-23 2020-02-23 15:55:48
# 512177  154            2  2020-02-23 2020-02-23 15:55:49
# 512178  154            2  2020-02-23 2020-02-23 15:55:50
# 512179  154            2  2020-02-23 2020-02-23 15:55:51
#
#                                 activity_type broad_activity_type  \
# 0                                WRK- general      work_education
# 1                                WRK- general      work_education
# 2                                WRK- general      work_education
# 3                                WRK- general      work_education
# 4                                WRK- general      work_education
# ...                                       ...                 ...
# 512175  EDU- taking class, research, homework      work_education
# 512176  EDU- taking class, research, homework      work_education
# 512177  EDU- taking class, research, homework      work_education
# 512178  EDU- taking class, research, homework      work_education
# 512179  EDU- taking class, research, homework      work_education
#
#                                 work_type  posture  sedentary_not  \
# 0       SP- Education and Health Services    stand  not_sedentary
# 1       SP- Education and Health Services    stand  not_sedentary
# 2       SP- Education and Health Services    stand  not_sedentary
# 3       SP- Education and Health Services    stand  not_sedentary
# 4       SP- Education and Health Services    stand  not_sedentary
# ...                                   ...      ...            ...
# 512175                               <NA>  sitting      sedentary
# 512176                               <NA>  sitting      sedentary
# 512177                               <NA>  sitting      sedentary
# 512178                               <NA>  sitting      sedentary
# 512179                               <NA>  sitting      sedentary
#
#         walking_not activity_intensity  Quality  Step  inside_flag
# 0       not_walking              light      NaN   NaN        False
# 1       not_walking              light  Codable   0.0         True
# 2       not_walking              light  Codable   0.0         True
# 3       not_walking              light  Codable   0.0         True
# 4       not_walking              light  Codable   0.0         True
# ...             ...                ...      ...   ...          ...
# 512175  not_walking          sedentary      NaN   NaN        False
# 512176  not_walking          sedentary      NaN   NaN        False
# 512177  not_walking          sedentary      NaN   NaN        False
# 512178  not_walking          sedentary      NaN   NaN        False
# 512179  not_walking          sedentary      NaN   NaN        False
#
# [512180 rows x 14 columns]

# %%
# Check to make sure that there is only one row per second
check = merged[["id", "observation", "date_time"]].value_counts()
check[check > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
merged["Quality"].value_counts()
# Out:
# Quality
# Codable         377920
# Non-codeable      6108
# Name: count, dtype: int64

# %% [markdown]
# ## Check Valid Rows (Intersection of Steps, Coding Tables)

# %% [markdown]
# At this point, we know that the rows are invalid if:
#
# 1. The ID and Session/observation are missing from the seconds ground truth entirely, not partially
# 2. OR They fall outside of where the time intervals of the two ground truth files intersect.
#
# We need to know if any more rows are invalid. The only rows that could be invalid at this point are rows that:
#
# 1. Have a valid ID/Session
# 2. AND they fall within the time interval
# 3. AND they either don't have steps or coding ground truth
#
# We need to check if any such rows exist.

# %%
# List of id/session that were found in the seconds file and in ground truth file
id_session_notna = start_end_info_3[["ID", "Session"]][~start_end_info_3["Start_secondsFile"].isna()]
id_session_notna
# Out:
#      ID  Session
# 0   102        1
# 1   102        2
# 2   116        1
# 3   116        2
# 4   117        1
# 5   117        2
# 6   122        1
# 7   122        2
# 8   124        1
# 9   124        2
# 11  126        2
# 12  127        1
# 13  127        2
# 14  128        1
# 15  128        2
# 16  129        1
# 17  129        2
# 18  130        1
# 19  130        2
# 20  131        1
# 22  132        1
# 23  132        2
# 24  133        1
# 25  133        2
# 26  134        1
# 28  135        1
# 29  135        2
# 30  136        1
# 32  138        1
# 36  140        1
# 37  140        2
# 38  141        1
# 39  141        2
# 40  143        1
# 41  143        2
# 42  144        1
# 43  144        2
# 44  150        1
# 45  150        2
# 47  154        2

# %%
# Find all valid rows - rows that should have data from both coding and step ground truth
# They should be in the valid id/sessions
merged_valid = id_session_notna.merge(right = merged, left_on = ["ID", "Session"], right_on = ["id", "observation"]).drop(["ID", "Session"], axis=1)
# They should also fall within the time interval between the max start and min end of both coding/step ground truth
merged_valid = merged_valid[merged_valid["inside_flag"] == True]
merged_valid
# Out:
#          id  observation        date           date_time  \
# 1       102            1  2019-07-24 2019-07-24 08:20:20
# 2       102            1  2019-07-24 2019-07-24 08:20:21
# 3       102            1  2019-07-24 2019-07-24 08:20:22
# 4       102            1  2019-07-24 2019-07-24 08:20:23
# 5       102            1  2019-07-24 2019-07-24 08:20:24
# ...     ...          ...         ...                 ...
# 416158  154            2  2020-02-23 2020-02-23 13:06:11
# 416159  154            2  2020-02-23 2020-02-23 13:06:12
# 416160  154            2  2020-02-23 2020-02-23 13:06:13
# 416161  154            2  2020-02-23 2020-02-23 13:06:14
# 416162  154            2  2020-02-23 2020-02-23 13:06:15
#
#                                 activity_type broad_activity_type  \
# 1                                WRK- general      work_education
# 2                                WRK- general      work_education
# 3                                WRK- general      work_education
# 4                                WRK- general      work_education
# 5                                WRK- general      work_education
# ...                                       ...                 ...
# 416158  EDU- taking class, research, homework      work_education
# 416159  EDU- taking class, research, homework      work_education
# 416160  EDU- taking class, research, homework      work_education
# 416161  EDU- taking class, research, homework      work_education
# 416162  EDU- taking class, research, homework      work_education
#
#                                 work_type         posture  sedentary_not  \
# 1       SP- Education and Health Services           stand  not_sedentary
# 2       SP- Education and Health Services           stand  not_sedentary
# 3       SP- Education and Health Services           stand  not_sedentary
# 4       SP- Education and Health Services           stand  not_sedentary
# 5       SP- Education and Health Services           stand  not_sedentary
# ...                                   ...             ...            ...
# 416158                               <NA>  stand and move  not_sedentary
# 416159                               <NA>  stand and move  not_sedentary
# 416160                               <NA>  stand and move  not_sedentary
# 416161                               <NA>  stand and move  not_sedentary
# 416162                               <NA>         sitting      sedentary
#
#         walking_not activity_intensity  Quality  Step  inside_flag
# 1       not_walking              light  Codable   0.0         True
# 2       not_walking              light  Codable   0.0         True
# 3       not_walking              light  Codable   0.0         True
# 4       not_walking              light  Codable   0.0         True
# 5       not_walking              light  Codable   1.0         True
# ...             ...                ...      ...   ...          ...
# 416158  not_walking              light  Codable   1.0         True
# 416159  not_walking              light  Codable   2.0         True
# 416160  not_walking              light  Codable   2.0         True
# 416161  not_walking              light  Codable   1.0         True
# 416162  not_walking          sedentary  Codable   2.0         True
#
# [383667 rows x 14 columns]

# %%
# Check if there are any invalid rows remaining - there should be none
merged_valid[(merged_valid["walking_not"].isna()) | (merged_valid["Step"].isna())]
# Out:
# Empty DataFrame
# Columns: [id, observation, date, date_time, activity_type, broad_activity_type, work_type, posture, sedentary_not, walking_not, activity_intensity, Quality, Step, inside_flag]
# Index: []

# %%
merged_valid["Quality"].value_counts()
# Out:
# Quality
# Codable         377559
# Non-codeable      6108
# Name: count, dtype: int64

# %% [markdown]
# Based on our analysis, there are no invalid rows that:
#
# 1. Have a valid ID/Session
# 2. AND they fall within the time interval
# 3. AND they either don't have steps or coding ground truth

# %% [markdown]
# ## Analyze Time Interval Disparity

# %% [markdown]
# Here we show the rows that have a valid ID/Session but fall outside the time interval intersection of the two ground truth tables. They should match the sum of the difference in seconds of the start/end that we calculated in the start_end_info tables.

# %%
# Find the total number of seconds/rows that fall outside the max start/min end interval
total_outside = start_end_info_3['StartDiffSecs(GT-seconds)'].abs().sum() + start_end_info_3['EndDiffSecs(GT-seconds)'].abs().sum()
total_outside
# Out:
# np.float64(42672.0)

# %%
merged_outside = merged[merged["inside_flag"] == False]
merged_outside
# Out:
#          id  observation        date           date_time  \
# 0       102            1  2019-07-24 2019-07-24 08:20:19
# 9919    102            1  2019-07-24 2019-07-24 11:05:38
# 9920    102            1  2019-07-24 2019-07-24 11:05:39
# 9921    102            1  2019-07-24 2019-07-24 11:05:40
# 9922    102            1  2019-07-24 2019-07-24 11:05:41
# ...     ...          ...         ...                 ...
# 512175  154            2  2020-02-23 2020-02-23 15:55:47
# 512176  154            2  2020-02-23 2020-02-23 15:55:48
# 512177  154            2  2020-02-23 2020-02-23 15:55:49
# 512178  154            2  2020-02-23 2020-02-23 15:55:50
# 512179  154            2  2020-02-23 2020-02-23 15:55:51
#
#                                 activity_type broad_activity_type  \
# 0                                WRK- general      work_education
# 9919                             WRK- general      work_education
# 9920                        WRK- screen based      work_education
# 9921                        WRK- screen based      work_education
# 9922                        WRK- screen based      work_education
# ...                                       ...                 ...
# 512175  EDU- taking class, research, homework      work_education
# 512176  EDU- taking class, research, homework      work_education
# 512177  EDU- taking class, research, homework      work_education
# 512178  EDU- taking class, research, homework      work_education
# 512179  EDU- taking class, research, homework      work_education
#
#                                                 work_type  posture  \
# 0                       SP- Education and Health Services    stand
# 9919    SP- Office (business, professional services, f...     walk
# 9920    SP- Office (business, professional services, f...  sitting
# 9921    SP- Office (business, professional services, f...  sitting
# 9922    SP- Office (business, professional services, f...  sitting
# ...                                                   ...      ...
# 512175                                               <NA>  sitting
# 512176                                               <NA>  sitting
# 512177                                               <NA>  sitting
# 512178                                               <NA>  sitting
# 512179                                               <NA>  sitting
#
#         sedentary_not  walking_not activity_intensity Quality  Step  \
# 0       not_sedentary  not_walking              light     NaN   NaN
# 9919    not_sedentary      walking           moderate     NaN   NaN
# 9920        sedentary  not_walking          sedentary     NaN   NaN
# 9921        sedentary  not_walking          sedentary     NaN   NaN
# 9922        sedentary  not_walking          sedentary     NaN   NaN
# ...               ...          ...                ...     ...   ...
# 512175      sedentary  not_walking          sedentary     NaN   NaN
# 512176      sedentary  not_walking          sedentary     NaN   NaN
# 512177      sedentary  not_walking          sedentary     NaN   NaN
# 512178      sedentary  not_walking          sedentary     NaN   NaN
# 512179      sedentary  not_walking          sedentary     NaN   NaN
#
#         inside_flag
# 0             False
# 9919          False
# 9920          False
# 9921          False
# 9922          False
# ...             ...
# 512175        False
# 512176        False
# 512177        False
# 512178        False
# 512179        False
#
# [42672 rows x 14 columns]

# %% [markdown]
# The numbers match up. We have the correct number of rows that fall outside the interval. Because they fall outside of the interval intersection, they will only have steps or coding ground truth, not both.
#
# We can further separate the two into rows that are in only coding and rows that are only in step count (that fall outside the common time interval intersection).

# %%
# Only in step count
sc_only = merged_outside[merged_outside["activity_type"].isna()]
sc_only
# Out:
#          id  observation date           date_time activity_type  \
# 10855   102            2  NaN 2019-07-25 12:41:53           NaN
# 10856   102            2  NaN 2019-07-25 12:41:54           NaN
# 10857   102            2  NaN 2019-07-25 12:41:55           NaN
# 10858   102            2  NaN 2019-07-25 12:41:56           NaN
# 10859   102            2  NaN 2019-07-25 12:41:57           NaN
# ...     ...          ...  ...                 ...           ...
# 501863  154            2  NaN 2020-02-23 13:03:55           NaN
# 501864  154            2  NaN 2020-02-23 13:03:56           NaN
# 501865  154            2  NaN 2020-02-23 13:03:57           NaN
# 501866  154            2  NaN 2020-02-23 13:03:58           NaN
# 501867  154            2  NaN 2020-02-23 13:03:59           NaN
#
#        broad_activity_type work_type posture sedentary_not walking_not  \
# 10855                  NaN      <NA>     NaN           NaN         NaN
# 10856                  NaN      <NA>     NaN           NaN         NaN
# 10857                  NaN      <NA>     NaN           NaN         NaN
# 10858                  NaN      <NA>     NaN           NaN         NaN
# 10859                  NaN      <NA>     NaN           NaN         NaN
# ...                    ...       ...     ...           ...         ...
# 501863                 NaN      <NA>     NaN           NaN         NaN
# 501864                 NaN      <NA>     NaN           NaN         NaN
# 501865                 NaN      <NA>     NaN           NaN         NaN
# 501866                 NaN      <NA>     NaN           NaN         NaN
# 501867                 NaN      <NA>     NaN           NaN         NaN
#
#        activity_intensity  Quality  Step  inside_flag
# 10855                 NaN  Codable   0.0        False
# 10856                 NaN  Codable   0.0        False
# 10857                 NaN  Codable   0.0        False
# 10858                 NaN  Codable   0.0        False
# 10859                 NaN  Codable   0.0        False
# ...                   ...      ...   ...          ...
# 501863                NaN  Codable   0.0        False
# 501864                NaN  Codable   0.0        False
# 501865                NaN  Codable   0.0        False
# 501866                NaN  Codable   0.0        False
# 501867                NaN  Codable   0.0        False
#
# [361 rows x 14 columns]

# %%
# Only in coding
gt_only = merged_outside[merged_outside["Step"].isna()]
gt_only
# Out:
#          id  observation        date           date_time  \
# 0       102            1  2019-07-24 2019-07-24 08:20:19
# 9919    102            1  2019-07-24 2019-07-24 11:05:38
# 9920    102            1  2019-07-24 2019-07-24 11:05:39
# 9921    102            1  2019-07-24 2019-07-24 11:05:40
# 9922    102            1  2019-07-24 2019-07-24 11:05:41
# ...     ...          ...         ...                 ...
# 512175  154            2  2020-02-23 2020-02-23 15:55:47
# 512176  154            2  2020-02-23 2020-02-23 15:55:48
# 512177  154            2  2020-02-23 2020-02-23 15:55:49
# 512178  154            2  2020-02-23 2020-02-23 15:55:50
# 512179  154            2  2020-02-23 2020-02-23 15:55:51
#
#                                 activity_type broad_activity_type  \
# 0                                WRK- general      work_education
# 9919                             WRK- general      work_education
# 9920                        WRK- screen based      work_education
# 9921                        WRK- screen based      work_education
# 9922                        WRK- screen based      work_education
# ...                                       ...                 ...
# 512175  EDU- taking class, research, homework      work_education
# 512176  EDU- taking class, research, homework      work_education
# 512177  EDU- taking class, research, homework      work_education
# 512178  EDU- taking class, research, homework      work_education
# 512179  EDU- taking class, research, homework      work_education
#
#                                                 work_type  posture  \
# 0                       SP- Education and Health Services    stand
# 9919    SP- Office (business, professional services, f...     walk
# 9920    SP- Office (business, professional services, f...  sitting
# 9921    SP- Office (business, professional services, f...  sitting
# 9922    SP- Office (business, professional services, f...  sitting
# ...                                                   ...      ...
# 512175                                               <NA>  sitting
# 512176                                               <NA>  sitting
# 512177                                               <NA>  sitting
# 512178                                               <NA>  sitting
# 512179                                               <NA>  sitting
#
#         sedentary_not  walking_not activity_intensity Quality  Step  \
# 0       not_sedentary  not_walking              light     NaN   NaN
# 9919    not_sedentary      walking           moderate     NaN   NaN
# 9920        sedentary  not_walking          sedentary     NaN   NaN
# 9921        sedentary  not_walking          sedentary     NaN   NaN
# 9922        sedentary  not_walking          sedentary     NaN   NaN
# ...               ...          ...                ...     ...   ...
# 512175      sedentary  not_walking          sedentary     NaN   NaN
# 512176      sedentary  not_walking          sedentary     NaN   NaN
# 512177      sedentary  not_walking          sedentary     NaN   NaN
# 512178      sedentary  not_walking          sedentary     NaN   NaN
# 512179      sedentary  not_walking          sedentary     NaN   NaN
#
#         inside_flag
# 0             False
# 9919          False
# 9920          False
# 9921          False
# 9922          False
# ...             ...
# 512175        False
# 512176        False
# 512177        False
# 512178        False
# 512179        False
#
# [42311 rows x 14 columns]

# %% [markdown]
# Some further analysis on the rows that are only in the coding ground truth:

# %%
gt_only_summary = gt_only['activity_type'].value_counts()
gt_only_summary = gt_only_summary.reset_index()
gt_only_summary = gt_only_summary.rename(columns = {"activity_type": "category"})
gt_only_summary['column'] = 'activity_type'

for col in ['broad_activity_type', 'work_type', 'posture', 'sedentary_not', 'walking_not', 'Quality']:
    new_summary = gt_only[col].value_counts()
    new_summary = new_summary.reset_index()
    new_summary = new_summary.rename(columns = {col: "category"})
    new_summary['column'] = col
    gt_only_summary = pd.concat([gt_only_summary, new_summary], axis=0)
    
gt_only_summary.groupby(["column", "category"]).sum()
# Out:
#                                                                         count
# column              category
# activity_type       CA- caring for and helping children                   418
#                     EAT- eating and drinking, waiting                    9520
#                     EDU- taking class, research, homework               11766
#                     EX- weight training                                     1
#                     HA- food prep and cleanup                              11
#                     HA- household management/other household activi...    474
#                     HA- lawn, garden and houseplants                       19
#                     LES- screen based leisure time (TV, video game,...   3163
#                     LES- socializing, communicating, leisure time n...   3213
#                     OTHER- non codable                                    179
#                     SL- sleep                                               1
#                     TRAV- walking                                           9
#                     WRK- general                                          990
#                     WRK- screen based                                   12547
# broad_activity_type active_transportation                                   9
#                     exercise                                                1
#                     household_personal                                    904
#                     lawn_garden                                            19
#                     leisure                                             15896
#                     non_codable                                           179
#                     work_education                                      25303
# posture             kneeling/ squatting                                    56
#                     lying                                                   1
#                     muscle strengthening                                    1
#                     private/not coded                                     245
#                     sitting                                             41118
#                     stand                                                 564
#                     stand and move                                        238
#                     walk                                                   86
#                     walk with load                                          2
# sedentary_not       non_codable                                           245
#                     not_sedentary                                         891
#                     sedentary                                           41175
# walking_not         non_codable                                           245
#                     not_walking                                         41978
#                     walking                                                88
# work_type           SP- Education and Health Services                    2655
#                     SP- Leisure and Hospiltality                          655
#                     SP- Office (business, professional services, fi...  10059
#                     SP- Trade, Retail, Transportation, and Utilities      167

# %% [markdown]
# **IMPORTANT NOTE**: Observed, most rows are non-walking, sedentary, sitting. We may re-add these rows to the dataset if we can confirm from Dr. Keadle that we can assume a step count of 0 for these rows.

# %% [markdown]
# Some further analysis on the rows only in step count:

# %%
sc_only['Step'].value_counts()
# Out:
# Step
# 0.0    341
# 1.0     11
# 2.0      9
# Name: count, dtype: int64

# %% [markdown]
# ## UPDATE: Impute Behavioral-Only with 0s and Re-Add to Data

# %% [markdown]
# All behavioral only rows have been determined to be 0 steps. We will impute and add back to the ground truth.

# %%
# Impute with 0s
gt_only2 = gt_only.copy()
gt_only2["Step"] = 0
gt_only2["Quality"] = "Codable"

# Add back to dataset
merged_valid2 = pd.concat([merged_valid, gt_only2], ignore_index=True).sort_values(["id", "observation", "date_time"])
merged_valid2
# Out:
#          id  observation        date           date_time  \
# 383667  102            1  2019-07-24 2019-07-24 08:20:19
# 0       102            1  2019-07-24 2019-07-24 08:20:20
# 1       102            1  2019-07-24 2019-07-24 08:20:21
# 2       102            1  2019-07-24 2019-07-24 08:20:22
# 3       102            1  2019-07-24 2019-07-24 08:20:23
# ...     ...          ...         ...                 ...
# 425973  154            2  2020-02-23 2020-02-23 15:55:47
# 425974  154            2  2020-02-23 2020-02-23 15:55:48
# 425975  154            2  2020-02-23 2020-02-23 15:55:49
# 425976  154            2  2020-02-23 2020-02-23 15:55:50
# 425977  154            2  2020-02-23 2020-02-23 15:55:51
#
#                                 activity_type broad_activity_type  \
# 383667                           WRK- general      work_education
# 0                                WRK- general      work_education
# 1                                WRK- general      work_education
# 2                                WRK- general      work_education
# 3                                WRK- general      work_education
# ...                                       ...                 ...
# 425973  EDU- taking class, research, homework      work_education
# 425974  EDU- taking class, research, homework      work_education
# 425975  EDU- taking class, research, homework      work_education
# 425976  EDU- taking class, research, homework      work_education
# 425977  EDU- taking class, research, homework      work_education
#
#                                 work_type  posture  sedentary_not  \
# 383667  SP- Education and Health Services    stand  not_sedentary
# 0       SP- Education and Health Services    stand  not_sedentary
# 1       SP- Education and Health Services    stand  not_sedentary
# 2       SP- Education and Health Services    stand  not_sedentary
# 3       SP- Education and Health Services    stand  not_sedentary
# ...                                   ...      ...            ...
# 425973                               <NA>  sitting      sedentary
# 425974                               <NA>  sitting      sedentary
# 425975                               <NA>  sitting      sedentary
# 425976                               <NA>  sitting      sedentary
# 425977                               <NA>  sitting      sedentary
#
#         walking_not activity_intensity  Quality  Step  inside_flag
# 383667  not_walking              light  Codable   0.0        False
# 0       not_walking              light  Codable   0.0         True
# 1       not_walking              light  Codable   0.0         True
# 2       not_walking              light  Codable   0.0         True
# 3       not_walking              light  Codable   0.0         True
# ...             ...                ...      ...   ...          ...
# 425973  not_walking          sedentary  Codable   0.0        False
# 425974  not_walking          sedentary  Codable   0.0        False
# 425975  not_walking          sedentary  Codable   0.0        False
# 425976  not_walking          sedentary  Codable   0.0        False
# 425977  not_walking          sedentary  Codable   0.0        False
#
# [425978 rows x 14 columns]

# %%
merged_valid2["Quality"].value_counts()
# Out:
# Quality
# Codable         419870
# Non-codeable      6108
# Name: count, dtype: int64

# %% [markdown]
# ## Analyze Missing IDs/Sessions from Steps Ground Truth

# %% [markdown]
# These rows correspond to coding ground truth ID/Sessions that are missing from the steps ground truth entirely.

# %%
# List of id/session that were found in ground truth file but NOT seconds file
id_session_na = start_end_info_3[["ID", "Session"]][start_end_info_3["Start_secondsFile"].isna()]
id_session_na
# Out:
#      ID  Session
# 10  126        1
# 21  131        2
# 27  134        2
# 31  136        2
# 33  138        2
# 34  139        1
# 35  139        2
# 46  154        1

# %%
merged_invalid_idsession = id_session_na.merge(right = merged, left_on = ["ID", "Session"], right_on = ["id", "observation"]).drop(["ID", "Session"], axis=1)
merged_invalid_idsession
# Out:
#         id  observation        date           date_time  \
# 0      126            1  2019-09-02 2019-09-02 11:14:51
# 1      126            1  2019-09-02 2019-09-02 11:14:52
# 2      126            1  2019-09-02 2019-09-02 11:14:53
# 3      126            1  2019-09-02 2019-09-02 11:14:54
# 4      126            1  2019-09-02 2019-09-02 11:14:55
# ...    ...          ...         ...                 ...
# 85836  154            1  2020-02-22 2020-02-22 16:06:55
# 85837  154            1  2020-02-22 2020-02-22 16:06:56
# 85838  154            1  2020-02-22 2020-02-22 16:06:57
# 85839  154            1  2020-02-22 2020-02-22 16:06:58
# 85840  154            1  2020-02-22 2020-02-22 16:06:59
#
#                                            activity_type  \
# 0      LES- socializing, communicating, leisure time ...
# 1      LES- socializing, communicating, leisure time ...
# 2      LES- socializing, communicating, leisure time ...
# 3      LES- socializing, communicating, leisure time ...
# 4      LES- socializing, communicating, leisure time ...
# ...                                                  ...
# 85836                                      TRAV- walking
# 85837                                      TRAV- walking
# 85838                                      TRAV- walking
# 85839                                      TRAV- walking
# 85840                                      TRAV- walking
#
#          broad_activity_type work_type  posture  sedentary_not  walking_not  \
# 0                    leisure      <NA>  sitting      sedentary  not_walking
# 1                    leisure      <NA>  sitting      sedentary  not_walking
# 2                    leisure      <NA>  sitting      sedentary  not_walking
# 3                    leisure      <NA>  sitting      sedentary  not_walking
# 4                    leisure      <NA>  sitting      sedentary  not_walking
# ...                      ...       ...      ...            ...          ...
# 85836  active_transportation      <NA>     walk  not_sedentary      walking
# 85837  active_transportation      <NA>     walk  not_sedentary      walking
# 85838  active_transportation      <NA>     walk  not_sedentary      walking
# 85839  active_transportation      <NA>     walk  not_sedentary      walking
# 85840  active_transportation      <NA>     walk  not_sedentary      walking
#
#       activity_intensity Quality  Step  inside_flag
# 0              sedentary     NaN   NaN         True
# 1              sedentary     NaN   NaN         True
# 2              sedentary     NaN   NaN         True
# 3              sedentary     NaN   NaN         True
# 38  150        2 2020-01-21 19:31:59 2020-01-21 22:32:00
# 39  154        2 2020-02-23 13:04:00 2020-02-23 15:55:51

# %% [markdown]
# Compare to log:

# %%
log = pd.read_csv("/Users/hydeet/Library/CloudStorage/OneDrive-CalPoly/StepCount/Eric's Analysis/Required datasets/do_log_final_behavior.csv")
log["Start"] = pd.to_datetime(log["start_month"].astype(str) + "/" +
                              log["start_day"].astype(str) + "/" +
                              log["start_year"].astype(str) + "/" + ' ' +
                              log["start_time"])
log["End"] = pd.to_datetime(log["start_month"].astype(str) + "/" +
                              log["start_day"].astype(str) + "/" +
                              log["start_year"].astype(str) + "/" + ' ' +
                              log["stop_time"])
log = log[['id', 'do', 'Start', 'End']].rename(columns = {"do": "Session", "id": "ID"})
log
# Out:
#      ID  Session               Start                 End
# 0   102        1 2019-07-24 08:20:19 2019-07-24 11:21:13
# 1   102        2 2019-07-25 12:42:08 2019-07-25 15:42:00
# 2   116        1 2019-08-20 08:08:45 2019-08-20 11:09:00
# 3   116        2 2019-08-21 11:09:47 2019-08-21 13:28:00
# 4   117        1 2019-08-20 15:17:46 2019-08-20 18:18:00
# 5   117        2 2019-08-21 07:11:45 2019-08-21 10:13:00
# 6   122        1 2019-08-28 10:06:40 2019-08-28 13:06:59
# 7   122        2 2019-08-29 15:19:51 2019-08-29 18:23:00
# 8   124        1 2019-08-28 14:59:09 2019-08-28 17:59:05
# 9   124        2 2019-08-29 09:31:00 2019-08-29 12:31:00
# 10  126        1 2019-09-02 11:14:51 2019-09-02 14:15:00
# 11  126        2 2019-09-06 10:36:07 2019-09-06 13:36:07
# 12  127        1 2019-09-05 16:07:56 2019-09-05 19:08:00
# 13  127        2 2019-09-09 10:56:00 2019-09-09 13:56:00
# 14  128        1 2019-09-06 07:00:00 2019-09-06 09:59:59
# 15  128        2 2019-09-10 13:21:00 2019-09-10 16:17:00
# 16  129        1 2019-09-07 08:55:00 2019-09-07 11:55:00
# 17  129        2 2019-09-10 16:31:45 2019-09-10 19:31:59
# 18  130        1 2019-09-08 17:27:53 2019-09-08 20:27:53
# 19  130        2 2019-09-10 08:02:01 2019-09-10 11:02:00
# 20  131        1 2019-09-12 10:57:42 2019-09-12 13:58:00
# 21  131        2 2019-09-16 09:04:54 2019-09-16 11:55:00
# 22  132        1 2019-10-04 13:31:17 2019-10-04 16:30:59
# 23  132        2 2019-10-10 09:24:44 2019-10-10 12:07:00
# 24  133        1 2019-10-10 14:31:56 2019-10-10 17:31:26
# 25  133        2 2019-10-11 10:23:20 2019-10-11 13:23:00
# 26  134        1 2019-10-09 12:57:00 2019-10-09 15:41:45
# 27  134        2 2019-10-13 12:56:53 2019-10-13 15:57:00
# 28  135        1 2019-10-15 15:32:01 2019-10-15 18:32:00
# 29  135        2 2019-10-19 12:49:51 2019-10-19 15:50:01
# 30  136        1 2019-10-17 13:41:00 2019-10-17 16:41:00
# 31  136        2 2019-10-19 09:00:51 2019-10-19 12:01:00
# 32  138        1 2019-11-01 16:11:00 2019-11-01 18:01:00
# 8  2019-08-28 17:59:05         0.0       0.0
# 9  2019-08-29 12:31:00         0.0       0.0
# 10 2019-09-02 14:15:00         NaN       NaN
# 11 2019-09-06 13:36:07         0.0       0.0
# 12 2019-09-05 19:08:00         0.0       0.0
# 13 2019-09-09 13:56:00         4.0       0.0
# 14 2019-09-06 09:59:59         0.0       0.0
# 15 2019-09-10 16:17:00         0.0       0.0
# 16 2019-09-07 11:55:00         0.0       0.0
# 17 2019-09-10 19:31:59         0.0       0.0
# 18 2019-09-08 20:27:53         0.0       0.0
# 19 2019-09-10 11:02:00         0.0       0.0
# 20 2019-09-12 13:58:00         0.0       0.0
# 21 2019-09-16 11:55:00         NaN       NaN
# 22 2019-10-04 16:30:59         0.0       0.0
# 23 2019-10-10 12:07:00        14.0       0.0
# 24 2019-10-10 17:31:26         0.0       0.0
# 25 2019-10-11 13:23:00         0.0       0.0
# 26 2019-10-09 15:41:45         0.0       0.0
# 27 2019-10-13 15:57:00         NaN       NaN
# 28 2019-10-15 18:32:00         0.0       0.0
# 29 2019-10-19 15:50:01         0.0       0.0
# 30 2019-10-17 16:41:00         0.0       0.0
# 31 2019-10-19 12:01:00         NaN       NaN
# 32 2019-11-01 18:01:00         0.0       0.0
# 33 2019-11-02 12:24:00         NaN       NaN
# 34 2019-11-03 17:20:00         NaN       NaN
# 35 2019-11-05 18:05:00         NaN       NaN
# 36 2019-11-09 11:59:01         0.0       0.0
# 37 2019-11-09 16:04:00         0.0       0.0
# 38 2019-11-06 15:29:00         0.0       0.0
# 39 2019-11-10 13:01:00         0.0       0.0
# 40 2019-11-18 16:01:58         0.0       0.0
# 41 2019-11-16 13:07:00         0.0       0.0
# 42 2019-11-22 15:39:00         0.0       0.0
# 43 2019-11-23 19:34:59         0.0       0.0
# 44 2020-01-19 13:18:26         0.0       0.0
# 45 2020-01-21 22:32:00         7.0       0.0
# 46 2020-02-22 16:06:59         NaN       NaN
# 47 2020-02-23 15:55:51         0.0       0.0

# %%
# log export for data pull
log_exp = log_compare.copy()
log_exp["Start"] = log_exp["Start_final"].combine_first(log_exp["Start_log"])
log_exp["End"] = log_exp["End_final"].combine_first(log_exp["End_log"])
log_exp[["ID", "Session", "Start", "End"]].to_csv("log-new.csv", index=False)

# %% [markdown]
# ## Final Table

# %% [markdown]
# **Final Ground Truth with Invalid Rows Dropped**

# %%
final_gt = merged_valid2.drop(["inside_flag"], axis=1).rename(columns={"Step": "step", "Quality": "quality"}).reset_index(drop=True)
# Zero out non-codeables
final_gt['step'] = final_gt['step'].astype(int) * (final_gt["quality"] == "Codable")
final_gt
# Out:
#          id  observation        date           date_time  \
# 0       102            1  2019-07-24 2019-07-24 08:20:19
# 1       102            1  2019-07-24 2019-07-24 08:20:20
# 2       102            1  2019-07-24 2019-07-24 08:20:21
# 3       102            1  2019-07-24 2019-07-24 08:20:22
# 4       102            1  2019-07-24 2019-07-24 08:20:23
# ...     ...          ...         ...                 ...
# 425973  154            2  2020-02-23 2020-02-23 15:55:47
# 425974  154            2  2020-02-23 2020-02-23 15:55:48
# 425975  154            2  2020-02-23 2020-02-23 15:55:49
# 425976  154            2  2020-02-23 2020-02-23 15:55:50
# 425977  154            2  2020-02-23 2020-02-23 15:55:51
#
#                                 activity_type broad_activity_type  \
# 0                                WRK- general      work_education
# 1                                WRK- general      work_education
# 2                                WRK- general      work_education
# 3                                WRK- general      work_education
# 4                                WRK- general      work_education
# ...                                       ...                 ...
# 425973  EDU- taking class, research, homework      work_education
# 425974  EDU- taking class, research, homework      work_education
# 425975  EDU- taking class, research, homework      work_education
# 425976  EDU- taking class, research, homework      work_education
# 425977  EDU- taking class, research, homework      work_education
#
#                                 work_type  posture  sedentary_not  \
# 0       SP- Education and Health Services    stand  not_sedentary
# 1       SP- Education and Health Services    stand  not_sedentary
# 2       SP- Education and Health Services    stand  not_sedentary
# 3       SP- Education and Health Services    stand  not_sedentary
# 4       SP- Education and Health Services    stand  not_sedentary
# ...                                   ...      ...            ...
# 425973                               <NA>  sitting      sedentary
# 425974                               <NA>  sitting      sedentary
# 425975                               <NA>  sitting      sedentary
# 425976                               <NA>  sitting      sedentary
# 425977                               <NA>  sitting      sedentary
#
#         walking_not activity_intensity  quality  step
# 0       not_walking              light  Codable     0
# 1       not_walking              light  Codable     0
# 2       not_walking              light  Codable     0
# 3       not_walking              light  Codable     0
# 4       not_walking              light  Codable     0
# ...             ...                ...      ...   ...
# 425973  not_walking          sedentary  Codable     0
# 425974  not_walking          sedentary  Codable     0
# 425975  not_walking          sedentary  Codable     0
# 425976  not_walking          sedentary  Codable     0
# 425977  not_walking          sedentary  Codable     0
#
# [425978 rows x 13 columns]

# %%
# Check non-codeables
final_gt[(final_gt["activity_type"] == "OTHER- non codable") | (final_gt["posture"] == "private/not coded")].groupby(["activity_type", "posture", "quality"])["step"].sum()
# Out:
# activity_type                                              posture            quality
# CA- caring for and helping children                        private/not coded  Codable          2
# EAT- eating and drinking, waiting                          private/not coded  Codable          0
# EX- surfing/water sport                                    private/not coded  Codable          0
# HA- household management/other household activities        private/not coded  Codable          2
#                                                                               Non-codeable     0
# HA- housework                                              private/not coded  Codable          0
# LES- screen based leisure time (TV, video game, computer)  private/not coded  Non-codeable     0
# LES- socializing, communicating, leisure time not screen   private/not coded  Codable          0
# OTHER- non codable                                         private/not coded  Codable         66
#                                                                               Non-codeable     0
#                                                            sitting            Codable          0
#                                                            stand              Codable         10
#                                                            stand and move     Codable         49
#                                                                               Non-codeable     0
#                                                            walk               Codable         24
#                                                                               Non-codeable     0
# PC- groom, health-related                                  private/not coded  Codable          4
# PUR- purchasing goods and services                         private/not coded  Codable          0
# TRAV- driver (car/truck/motorcycle)                        private/not coded  Codable          0
# TRAV- passenger (car/truck/motorcycle)                     private/not coded  Codable          0
# TRAV- walking                                              private/not coded  Codable          1
#                                                                               Non-codeable     0
# WRK- general                                               private/not coded  Codable         16
#                                                                               Non-codeable     0
# Name: step, dtype: int64

# %%
final_gt["quality"].value_counts()
# Out:
# quality
# Codable         419870
# Non-codeable      6108
# Name: count, dtype: int64

# %%
# Create relative time variable at the very end

# Ensure date_time is datetime type
final_gt["date_time"] = pd.to_datetime(final_gt["date_time"])

# Group by id and observation and subtract the min date_time from each row in that group
final_gt["relative_time"] = (
    final_gt.groupby(["id", "observation"])["date_time"]
    .transform(lambda x: x - x.min())
)

# Format timedelta to HH:MM:SS string
final_gt["relative_time"] = final_gt["relative_time"].apply(lambda x: str(x).split()[-1])

# Get list of columns
cols = list(final_gt.columns)

# Find the index of 'date_time'
idx = cols.index("date_time")

# Remove 'relative_time' from its current position
cols.remove("relative_time")

# Insert 'relative_time' right after 'date_time'
cols.insert(idx + 1, "relative_time")

# Reorder the DataFrame
final_gt = final_gt[cols]

final_gt
# Out:
#          id  observation        date           date_time relative_time  \
# 0       102            1  2019-07-24 2019-07-24 08:20:19      00:00:00
# 1       102            1  2019-07-24 2019-07-24 08:20:20      00:00:01
# 2       102            1  2019-07-24 2019-07-24 08:20:21      00:00:02
# 3       102            1  2019-07-24 2019-07-24 08:20:22      00:00:03
# 4       102            1  2019-07-24 2019-07-24 08:20:23      00:00:04
# ...     ...          ...         ...                 ...           ...
# 425973  154            2  2020-02-23 2020-02-23 15:55:47      02:51:47
# 425974  154            2  2020-02-23 2020-02-23 15:55:48      02:51:48
# 425975  154            2  2020-02-23 2020-02-23 15:55:49      02:51:49
# 425976  154            2  2020-02-23 2020-02-23 15:55:50      02:51:50
# 425977  154            2  2020-02-23 2020-02-23 15:55:51      02:51:51
#
#                                 activity_type broad_activity_type  \
# 0                                WRK- general      work_education
# 1                                WRK- general      work_education
# 2                                WRK- general      work_education
# 3                                WRK- general      work_education
# 4                                WRK- general      work_education
# ...                                       ...                 ...
# 425973  EDU- taking class, research, homework      work_education
# 425974  EDU- taking class, research, homework      work_education
# 425975  EDU- taking class, research, homework      work_education
# 425976  EDU- taking class, research, homework      work_education
# 425977  EDU- taking class, research, homework      work_education
#
#                                 work_type  posture  sedentary_not  \
# 0       SP- Education and Health Services    stand  not_sedentary
# 1       SP- Education and Health Services    stand  not_sedentary
# 2       SP- Education and Health Services    stand  not_sedentary
# 3       SP- Education and Health Services    stand  not_sedentary
# 4       SP- Education and Health Services    stand  not_sedentary
# ...                                   ...      ...            ...
# 425973                               <NA>  sitting      sedentary
# 425974                               <NA>  sitting      sedentary
# 425975                               <NA>  sitting      sedentary
# 425976                               <NA>  sitting      sedentary
# 425977                               <NA>  sitting      sedentary
#
#         walking_not activity_intensity  quality  step
# 0       not_walking              light  Codable     0
# 1       not_walking              light  Codable     0
# 2       not_walking              light  Codable     0
# 3       not_walking              light  Codable     0
# 4       not_walking              light  Codable     0
# ...             ...                ...      ...   ...
# 425973  not_walking          sedentary  Codable     0
# 425974  not_walking          sedentary  Codable     0
# 425975  not_walking          sedentary  Codable     0
# 425976  not_walking          sedentary  Codable     0
# 425977  not_walking          sedentary  Codable     0
#
# [425978 rows x 14 columns]

# %%
# Eric making the manual changes that Sarah emailed about for ID 128 obs 1
# Define filtering mask
mask = (
    (final_gt["id"] == 128) &
    (final_gt["observation"] == 1) &
    (final_gt["date_time"] >= pd.to_datetime("9/6/2019  7:07:40 AM")) &
    (final_gt["date_time"] <= pd.to_datetime("9/6/2019  7:36:14 AM"))
)

# Apply the manual updates
final_gt.loc[mask, "quality"] = "Non-codeable"

#Check that it worked
final_gt.loc[mask, ["id", "observation", "date_time", "quality"]]
# Out:
#          id  observation           date_time       quality
# 138695  128            1 2019-09-06 07:07:40  Non-codeable
# 138696  128            1 2019-09-06 07:07:41  Non-codeable
# 138697  128            1 2019-09-06 07:07:42  Non-codeable
# 138698  128            1 2019-09-06 07:07:43  Non-codeable
# 138699  128            1 2019-09-06 07:07:44  Non-codeable
# ...     ...          ...                 ...           ...
# 140405  128            1 2019-09-06 07:36:10  Non-codeable
# 140406  128            1 2019-09-06 07:36:11  Non-codeable
# 140407  128            1 2019-09-06 07:36:12  Non-codeable
# 140408  128            1 2019-09-06 07:36:13  Non-codeable
# 140409  128            1 2019-09-06 07:36:14  Non-codeable
#
# [1715 rows x 4 columns]

# %%
final_gt.to_csv("merged_groundtruth_secbysec_20250415.csv", index=False)

# %% [markdown]
# Export with noncodeable omitted to send to Dr. Keadle and Paige

# %%
final_with_drops = final_gt[(final_gt["activity_type"] != "OTHER- non codable") & (final_gt["posture"] != "private/not coded") & (final_gt["quality"] == "Codable")]
final_with_drops
# Out:
#          id  observation        date           date_time relative_time  \
# 0       102            1  2019-07-24 2019-07-24 08:20:19      00:00:00
# 1       102            1  2019-07-24 2019-07-24 08:20:20      00:00:01
# 2       102            1  2019-07-24 2019-07-24 08:20:21      00:00:02
# 3       102            1  2019-07-24 2019-07-24 08:20:22      00:00:03
# 4       102            1  2019-07-24 2019-07-24 08:20:23      00:00:04
# ...     ...          ...         ...                 ...           ...
# 425973  154            2  2020-02-23 2020-02-23 15:55:47      02:51:47
# 425974  154            2  2020-02-23 2020-02-23 15:55:48      02:51:48
# 425975  154            2  2020-02-23 2020-02-23 15:55:49      02:51:49
# 425976  154            2  2020-02-23 2020-02-23 15:55:50      02:51:50
# 425977  154            2  2020-02-23 2020-02-23 15:55:51      02:51:51
#
#                                 activity_type broad_activity_type  \
# 0                                WRK- general      work_education
# 1                                WRK- general      work_education
# 2                                WRK- general      work_education
# 3                                WRK- general      work_education
# 4                                WRK- general      work_education
# ...                                       ...                 ...
# 425973  EDU- taking class, research, homework      work_education
# 425974  EDU- taking class, research, homework      work_education
# 425975  EDU- taking class, research, homework      work_education
# 425976  EDU- taking class, research, homework      work_education
# 425977  EDU- taking class, research, homework      work_education
#
#                                 work_type  posture  sedentary_not  \
# 0       SP- Education and Health Services    stand  not_sedentary
# 1       SP- Education and Health Services    stand  not_sedentary
# 2       SP- Education and Health Services    stand  not_sedentary
# 3       SP- Education and Health Services    stand  not_sedentary
# 4       SP- Education and Health Services    stand  not_sedentary
# ...                                   ...      ...            ...
# 425973                               <NA>  sitting      sedentary
# 425974                               <NA>  sitting      sedentary
# 425975                               <NA>  sitting      sedentary
# 425976                               <NA>  sitting      sedentary
# 425977                               <NA>  sitting      sedentary
#
#         walking_not activity_intensity  quality  step
# 0       not_walking              light  Codable     0
# 1       not_walking              light  Codable     0
# 2       not_walking              light  Codable     0
# 3       not_walking              light  Codable     0
# 4       not_walking              light  Codable     0
# ...             ...                ...      ...   ...
# 425973  not_walking          sedentary  Codable     0
# 425974  not_walking          sedentary  Codable     0
# 425975  not_walking          sedentary  Codable     0
# 425976  not_walking          sedentary  Codable     0
# 425977  not_walking          sedentary  Codable     0
#
# [401689 rows x 14 columns]

# %%
# Eric making the manual changes that Sarah outlined in documenting_changes.docx
# First, ID 116 obs 2
# Define filtering mask
mask = (
    (final_with_drops["id"] == 116) &
    (final_with_drops["observation"] == 2) &
    (final_with_drops["date_time"] >= pd.to_datetime("8/21/2019 11:43:47 AM")) &
    (final_with_drops["date_time"] <= pd.to_datetime("8/21/2019 11:45:57 AM"))
)

# Apply the manual updates
final_with_drops.loc[mask, "posture"] = "stand and move"
final_with_drops.loc[mask, "sedentary_not"] = "not_sedentary"
final_with_drops.loc[mask, "activity_intensity"] = "light"

#Check that it worked
final_with_drops.loc[mask, ["id", "observation", "date_time", "posture", "sedentary_not", "activity_intensity"]]
# Out:
#         id  observation           date_time         posture  sedentary_not  \
# 34479  116            2 2019-08-21 11:43:47  stand and move  not_sedentary
# 34480  116            2 2019-08-21 11:43:48  stand and move  not_sedentary
# 34481  116            2 2019-08-21 11:43:49  stand and move  not_sedentary
# 34482  116            2 2019-08-21 11:43:50  stand and move  not_sedentary
# 34483  116            2 2019-08-21 11:43:51  stand and move  not_sedentary
# ...    ...          ...                 ...             ...            ...
# 34605  116            2 2019-08-21 11:45:53  stand and move  not_sedentary
# 34606  116            2 2019-08-21 11:45:54  stand and move  not_sedentary
# 34607  116            2 2019-08-21 11:45:55  stand and move  not_sedentary
# 34608  116            2 2019-08-21 11:45:56  stand and move  not_sedentary
# 34609  116            2 2019-08-21 11:45:57  stand and move  not_sedentary
#
#       activity_intensity
# 34479              light
# 34480              light
# 34481              light
# 34482              light
# 34483              light
# ...                  ...
# 34605              light
# 34606              light
# 34607              light
# 34608              light
# 34609              light
#
# [131 rows x 6 columns]

# %%
# ID 117 obs 1
# Define filtering mask
mask = (
    (final_with_drops["id"] == 117) &
    (final_with_drops["observation"] == 1) &
    (final_with_drops["date_time"] >= pd.to_datetime("8/20/2019  6:05:40 PM")) &
    (final_with_drops["date_time"] <= pd.to_datetime("8/20/2019  6:05:55 PM"))
)

# Apply the manual updates
final_with_drops.loc[mask, "posture"] = "stand and move"
final_with_drops.loc[mask, "sedentary_not"] = "not_sedentary"
final_with_drops.loc[mask, "activity_intensity"] = "light"

#Check that it worked
final_with_drops.loc[mask, ["id", "observation", "date_time", "posture", "sedentary_not", "activity_intensity"]]
# Out:
#         id  observation           date_time         posture  sedentary_not  \
# 50807  117            1 2019-08-20 18:05:40  stand and move  not_sedentary
# 50808  117            1 2019-08-20 18:05:41  stand and move  not_sedentary
# 50809  117            1 2019-08-20 18:05:42  stand and move  not_sedentary
# 50810  117            1 2019-08-20 18:05:43  stand and move  not_sedentary
# 50811  117            1 2019-08-20 18:05:44  stand and move  not_sedentary
# 50812  117            1 2019-08-20 18:05:45  stand and move  not_sedentary
# 50813  117            1 2019-08-20 18:05:46  stand and move  not_sedentary
# 50814  117            1 2019-08-20 18:05:47  stand and move  not_sedentary
# 50815  117            1 2019-08-20 18:05:48  stand and move  not_sedentary
# 50816  117            1 2019-08-20 18:05:49  stand and move  not_sedentary
# 50817  117            1 2019-08-20 18:05:50  stand and move  not_sedentary
# 50818  117            1 2019-08-20 18:05:51  stand and move  not_sedentary
# 50819  117            1 2019-08-20 18:05:52  stand and move  not_sedentary
# 50820  117            1 2019-08-20 18:05:53  stand and move  not_sedentary
# 50821  117            1 2019-08-20 18:05:54  stand and move  not_sedentary
# 50822  117            1 2019-08-20 18:05:55  stand and move  not_sedentary
#
#       activity_intensity
# 50807              light
# 50808              light
# 50809              light
# 50810              light
# 50811              light
# 50812              light
# 50813              light
# 50814              light
# 50815              light
# 50816              light
# 50817              light
# 50818              light
# 50819              light
# 50820              light
# 50821              light
# 50822              light

# %%
# ID 128 obs 2
# Define filtering mask
mask = (
    (final_with_drops["id"] == 128) &
    (final_with_drops["observation"] == 2) &
    (final_with_drops["date_time"] >= pd.to_datetime("9/10/2019  2:40:36 PM")) &
    (final_with_drops["date_time"] <= pd.to_datetime("9/10/2019  2:42:57 PM"))
)

# Apply the manual updates
final_with_drops.loc[mask, "posture"] = "stand and move"
final_with_drops.loc[mask, "sedentary_not"] = "not_sedentary"
final_with_drops.loc[mask, "activity_intensity"] = "light"

#Check that it worked
final_with_drops.loc[mask, ["id", "observation", "date_time", "posture", "sedentary_not", "activity_intensity"]]
# Out:
#          id  observation           date_time         posture  sedentary_not  \
# 153811  128            2 2019-09-10 14:40:36  stand and move  not_sedentary
# 153812  128            2 2019-09-10 14:40:37  stand and move  not_sedentary
# 153813  128            2 2019-09-10 14:40:38  stand and move  not_sedentary
# 153814  128            2 2019-09-10 14:40:39  stand and move  not_sedentary
# 153815  128            2 2019-09-10 14:40:40  stand and move  not_sedentary
# ...     ...          ...                 ...             ...            ...
# 153948  128            2 2019-09-10 14:42:53  stand and move  not_sedentary
# 153949  128            2 2019-09-10 14:42:54  stand and move  not_sedentary
# 153950  128            2 2019-09-10 14:42:55  stand and move  not_sedentary
# 153951  128            2 2019-09-10 14:42:56  stand and move  not_sedentary
# 153952  128            2 2019-09-10 14:42:57  stand and move  not_sedentary
#
#        activity_intensity
# 153811              light
# 153812              light
# 153813              light
# 153814              light
# 153815              light
# ...                   ...
# 153948              light
# 153949              light
# 153950              light
# 153951              light
# 153952              light
#
# [142 rows x 6 columns]

# %%
final_with_drops.to_csv(
    "merged_groundtruth_secbysec_clean_20250415.csv",
    index=False,
    date_format="%m/%d/%Y %H:%M:%S")
