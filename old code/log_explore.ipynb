# %%
import pandas as pd
import numpy as np

# %%
act_log_df = pd.read_csv("C:/Users/HELIOS-300/Downloads/do_log_final_behavior(in).csv")
am_log_df = pd.read_csv("C:/Users/HELIOS-300/Desktop/Data/DO_LOG_final.csv", encoding='utf-8')

# %%
act_log_df.head(20)
# Out:
#      id  do  start_month  start_day  start_year   start_time    stop_time  \
# 0   102   1            7         24        2019   8:20:19 AM  11:21:13 AM
# 1   102   2            7         25        2019  12:42:08 PM   3:42:00 PM
# 2   116   1            8         20        2019   8:08:45 AM  11:09:00 AM
# 3   116   2            8         21        2019  11:09:47 AM   1:28:00 PM
# 4   117   1            8         20        2019   3:17:46 PM   6:18:00 PM
# 5   117   2            8         21        2019   7:11:45 AM  10:13:00 AM
# 6   122   1            8         28        2019  10:06:40 AM   1:06:59 PM
# 7   122   2            8         29        2019   3:19:51 PM   6:23:00 PM
# 8   124   1            8         28        2019   2:59:09 PM   5:59:05 PM
# 9   124   2            8         29        2019   9:31:00 AM  12:31:00 PM
# 10  126   1            9          2        2019  11:14:51 AM   2:15:00 PM
# 11  126   2            9          6        2019  10:36:07 AM   1:36:07 PM
# ...

# %%
am_log_df.head(20)
# Out:
#       id    obs type  start_month  start_day  start_year start_time stop_time  \
# 0   AM01    DO2    L           10          3        2017   18:44:45  20:47:00
# 1   AM01    DO1    H           10          6        2017   16:43:57  18:45:00
# 2   AM02    DO1    H            7         24        2017   13:17:10  15:17:32
# 3   AM02  DO2_a    A            7         25        2017    8:00:27   8:52:32
# 4   AM02  DO2_b    A            7         25        2017    8:56:13  10:12:29
# 5   AM03    DO1    L            7         25        2017   14:00:10  16:00:23
# 6   AM03    DO2    H            7         27        2017   13:01:29  15:00:39
# 7   AM04    DO1    W            9         12        2017   12:02:56  14:04:00
# 8   AM04    DO2    A            9         17        2017   14:15:58  16:16:00
# 9   AM05    DO2    L            9         19        2017   19:38:53  21:40:00
# 10  AM06    DO1    E            7         31        2017    8:35:23  10:36:03
# ...
